# %%
import pandas as pd
julho = pd.read_csv('focos mensal.csv', sep=',')
logic = julho["pais"] == "Brasil"
julho = julho.loc[logic]
logic = julho["bioma"] == "Cerrado"
julho = julho.loc[logic]
julho
# Out:
# c:\venv\ilumpy\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                            id        lat        lon  \
# 4599     7f99bb2a-b101-3f0e-828f-195bec959c67 -10.090000 -44.360000
# 4600     ac61d1b3-6aa1-3240-bc74-56ba20e5b50c -10.060000 -44.360000
# 4601     0068ea90-6fed-3af8-98ff-4ca211388689 -10.090000 -44.410000
# 4606     8c489fef-ab87-3f1d-b900-af2d55f18411 -22.795401 -49.362499
# 4607     2867cc62-8022-3c65-87c2-4dfc611f3517 -22.797701 -49.371899
# ...                                       ...        ...        ...
# 3778045  538236cc-8e35-3bef-b980-fddbace50583 -12.620000 -44.420000
# 3778052  ef053ce9-405c-3de4-a12a-afe15d90a640 -11.360000 -47.360000
# 3778053  ecbc6957-e94a-33aa-a7fc-02822522b9ae -10.650000 -48.810000
# ...

# %%
import pandas as pd
junho = pd.read_csv('focos mensal junho.csv', sep=',')
logic = junho["pais"] == "Brasil"
junho = junho.loc[logic]
logic = junho["bioma"] == "Cerrado"
junho = junho.loc[logic]
junho
# Out:
# c:\venv\ilumpy\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                            id    lat    lon  \
# 217      ec7e60ce-0191-38d3-adc9-aaea7abaf521 -14.66 -50.45
# 218      584b0379-949e-322d-9f51-c035c2d61ff6 -14.66 -50.47
# 223      e90c92ff-f4b7-35b1-bfe3-6dbe49e8a2f0 -10.83 -50.86
# 228      01f80526-5147-3100-b9b0-3161557d3591  -8.69 -49.06
# 447      93fd8b92-ecdc-3911-99bb-7cdfc6fa9c88 -14.66 -50.47
# ...                                       ...    ...    ...
# 2259104  ff1aef76-9805-34c8-acd5-1bbef25b2685 -13.91 -59.68
# 2259105  a7224173-4659-3129-8876-0af4487911d4 -13.91 -59.70
# 2259106  b4801f0f-288f-34f6-b592-86b85ee9c268 -13.89 -59.69
# 2259107  e0f82eb5-7698-3fc9-9eb8-5532c27c761b -13.89 -59.71
# 2259108  c8febccd-b84d-3d4c-b1ad-1f69b3fda2d2 -13.80 -45.04
#
# ...

# %%
import pandas as pd
maio = pd.read_csv('focos mensal maio.csv', sep=',')
logic = maio["pais"] == "Brasil"
maio = maio.loc[logic]
logic = maio["bioma"] == "Cerrado"
maio = maio.loc[logic]
maio
# Out:
#                                            id       lat       lon  \
# 1649     d2be2e7d-c716-33c8-ab67-7ca35ff23b2b -18.45775 -51.25215
# 1650     c358ba58-edcf-37d8-904b-38b50110db13 -14.46447 -48.89709
# 1651     960c7f39-c1c4-3e02-b02c-d7a4248b2fee -13.96734 -46.46752
# 1652     da76cf23-b728-39f5-8862-1fe42f84e2d3  -9.08194 -49.34354
# 1655     4535800e-0a62-3d9b-92d9-d0d919ae9e55 -13.56871 -56.48854
# ...                                       ...       ...       ...
# 2203103  a183cab0-7c35-3587-aab4-1a0bd34e9ee8 -17.46354 -52.59166
# 2203107  52466c49-5e23-3f96-a4cb-fbecfb306ea4 -20.04477 -54.70036
# 2203125  f5fc1677-5955-3c87-858b-78402e238d0b -10.87000 -49.66000
# 2203126  69202e13-fafa-3bd3-91f0-e427e1874573 -10.37000 -50.37000
# 2203127  4b2e29dd-7e9c-3bd9-a2d1-f5e617084cef -10.22000 -46.23000
#
#                data_hora_gmt   satelite                 municipio  \
# 1649     2022-05-01 01:54:00  TERRA_M-M                      CAÇU
# ...

# %%
import pandas as pd
abril = pd.read_csv('focos mensal abril.csv', sep=',')
logic = abril["pais"] == "Brasil"
abril = abril.loc[logic]
logic = abril["bioma"] == "Cerrado"
abril = abril.loc[logic]
abril
# Out:
# c:\venv\ilumpy\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                            id       lat       lon  \
# 49       57df7b8a-1678-3a58-9e19-f4c08f7270b8 -13.43000 -45.50000
# 50       21b58675-d02c-3207-ba1e-d408f9bf644c -13.43000 -45.52000
# 776      fc199570-7505-3ad9-86e7-c129dcb94cd0 -13.43000 -45.52000
# 777      da21eef5-88b6-32ab-bc58-bc5eda5fcbd1 -13.43000 -45.50000
# 868      23c6d439-2081-39cd-b15e-fa36015b61f5 -13.43000 -45.52000
# ...                                       ...       ...       ...
# 1011641  a5d1e123-aeb1-3db2-b8d0-09d24fc1a1ba -15.44294 -55.83731
# 1011642  8847ea20-1a60-3b4d-8529-f211dac67f77 -15.44235 -55.83553
# 1011643  e4af652f-0ca4-3191-a9a6-8b5ed47bbd89 -15.41218 -55.86840
# 1011648  c0f05a1a-a71e-33a0-9567-3b06331db6ef -15.40793 -55.87184
# ...

# %%
import pandas as pd
marco = pd.read_csv('focos mensal marco.csv', sep=',')
logic = marco["pais"] == "Brasil"
marco = marco.loc[logic]
logic = marco["bioma"] == "Cerrado"
marco = marco.loc[logic]
marco
# Out:
# c:\venv\ilumpy\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                            id      lat        lon  \
# 25       59e08856-55e9-3b6a-956c-f6cdadf2d0c0 -21.0700 -48.400000
# 26       cee0fa36-a165-396a-bae0-c2104b2569f3 -21.0700 -48.370000
# 30       3c1aea26-e880-39e3-b4a9-5cb3d1407492 -13.0462 -43.528999
# 31       b7035f6a-260e-3394-846f-62fc69460e57 -11.4455 -43.295601
# 98       29d8b35b-10b1-3485-8ac7-64b66c825902 -21.0700 -48.400000
# ...                                       ...      ...        ...
# 2915104  d833e931-7cc3-3974-b1c5-047b0083dd04 -13.4300 -45.520000
# 2915197  3d9dce82-7614-3975-bfe8-b4292632ba5a -16.9900 -46.110000
# 2915198  345e7f13-75c9-33f7-a798-9b76c810c6e0 -13.4300 -45.520000
# 2915302  70c1eb5e-6a0c-363c-8ecf-610f333db30b -16.9900 -46.110000
# ...

# %%
import pandas as pd
fev = pd.read_csv('focos mensal fev.csv', sep=',')
logic = fev["pais"] == "Brasil"
fev = fev.loc[logic]
logic = fev["bioma"] == "Cerrado"
fev = fev.loc[logic]
fev
# Out:
# c:\venv\ilumpy\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                            id       lat       lon  \
# 14979    fe4f94a7-1732-3a3e-8277-9277748eb722  -4.99344 -43.77810
# 14980    187dc1c8-6359-398b-8951-211296b4ea08  -4.99233 -43.78469
# 14981    e1af11e6-ccfc-395e-b57d-b8bc68702613  -5.88530 -45.43486
# 14982    63d45648-bc0c-3954-8f5b-b16914e0bb29  -4.99289 -43.78138
# 14983    4383ff68-0ea7-3007-8dd0-ac79aaf6627e  -4.98816 -43.77710
# ...                                       ...       ...       ...
# 1043676  59320bac-ffd2-3757-8e54-8fef49e121d9 -20.89000 -55.77000
# 1043696  3703e729-da1f-3575-b6e7-95ab867237c4 -20.89000 -55.77000
# 1043714  b996d9d1-e82c-3eab-8664-523b8de5b757 -20.89000 -55.77000
# 1048387  e8a4c569-7242-3f02-805b-523e69913a0c -20.89000 -55.77000
# ...

# %%
import pandas as pd
jan = pd.read_csv('focos mensal jan.csv', sep=',')
logic = jan["pais"] == "Brasil"
jan = jan.loc[logic]
logic = jan["bioma"] == "Cerrado"
jan = jan.loc[logic]
jan
# Out:
# c:\venv\ilumpy\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                           id       lat       lon  \
# 7580    14b0c9be-2d80-34c6-83e4-6861ffe1d8db -21.23028 -54.15346
# 7582    bd0c000d-f953-39db-8625-0ac1ee8c9d65 -20.69813 -56.59095
# 7583    0fa79c47-f911-3d54-bc99-33ad8aea69b0 -20.70350 -56.59228
# 7584    ebf8324c-890c-379c-ad06-6f2055ead386 -22.53972 -48.81057
# 7588    d0b0e269-fa11-3982-874a-5d03a0760404 -21.22959 -54.15133
# ...                                      ...       ...       ...
# 901213  9bde8443-2060-353d-8f7f-1d3762a6a44a -21.12444 -54.65271
# 901285  4a0cf366-9797-353e-9f42-233204d5d327 -23.98271 -48.91854
# 903254  345094ba-d323-32af-824e-50eaf0cadb3c -19.85421 -55.06334
# 903267  88c7af90-f737-3a2e-97e0-386d86abbfc7 -19.85463 -55.05865
# ...
